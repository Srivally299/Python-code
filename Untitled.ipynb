# %%
import pandas as  pd

# %%
df = pd.read_csv(r'C:\Users\Srivally\Downloads\Cantellat Internship\FIN_MAR12_MAR21_DATA.txt',sep="|")

# %%
display(df)
# Out:
#        ca_finance1_cocode              ca_company_name ca_finance1_year  \
# 0                      11              20 MICRONS LTD.       2012-03-31
# 1                      11              20 MICRONS LTD.       2013-03-31
# 2                      11              20 MICRONS LTD.       2014-03-31
# 3                      11              20 MICRONS LTD.       2015-03-31
# 4                      11              20 MICRONS LTD.       2016-03-31
# ...                   ...                          ...              ...
# 17042              656295                   C W D LTD.       2020-03-31
# 17043              656295                   C W D LTD.       2021-03-31
# 17044              656548  WHERRELZ I T SOLUTIONS LTD.       2019-03-31
# 17045              656548  WHERRELZ I T SOLUTIONS LTD.       2020-03-31
# 17046              656548  WHERRELZ I T SOLUTIONS LTD.       2021-03-31
#
#        ca_ann_rep_months ca_fs_format  ca_total_income  ca_sales  \
# ...

# %%
df = pd.read_csv(r'C:\Users\Srivally\Downloads\Cantellat Internship\RPT_MAR12_MAR21_DATA.txt',sep="|")

# %%
display(df)
# Out:
#         rpt_cocode                   company_name    rpt_date  rpt_party_type  \
# 0               11                20 MICRONS LTD.  2012-03-31             200
# 1               11                20 MICRONS LTD.  2012-03-31             200
# 2               11                20 MICRONS LTD.  2012-03-31             200
# 3               11                20 MICRONS LTD.  2012-03-31             200
# 4               11                20 MICRONS LTD.  2012-03-31             200
# ...            ...                            ...         ...             ...
# 877290      658574          S P REFRACTORIES LTD.  2021-03-31             200
# 877291      658574          S P REFRACTORIES LTD.  2021-03-31            9999
# 877292      659294  EKENNIS SOFTWARE SERVICE LTD.  2021-03-31             200
# 877293      659294  EKENNIS SOFTWARE SERVICE LTD.  2021-03-31             200
# 877294      659294  EKENNIS SOFTWARE SERVICE LTD.  2021-03-31            9999
#
# ...

# %%
df = pd.read_csv(r'C:\Users\Srivally\Downloads\Cantellat Internship\BoD_MAR12_MAR21_DATA.txt',sep="|")

# %%
display(df)
# Out:
#         co_code        company_name                      directors_name  \
# 0            11     20 MICRONS LTD.                       ATIL C PARIKH
# 1            11     20 MICRONS LTD.                        ATUL H PATEL
# 2            11     20 MICRONS LTD.                    CHANDRESH PARIKH
# 3            11     20 MICRONS LTD.                         MIHIR JOSHI
# 4            11     20 MICRONS LTD.                        MUNISH MOHAN
# ...         ...                 ...                                 ...
# 933135   659714  EVOQ REMEDIES LTD.  KOMALBEN PATEL VASHISTHBHAI (MRS.)
# 933136   659714  EVOQ REMEDIES LTD.        BHUMISHTH NARENDRABHAI PATEL
# 933137   659714  EVOQ REMEDIES LTD.  KOMALBEN PATEL VASHISTHBHAI (MRS.)
# 933138   659714  EVOQ REMEDIES LTD.                       PAYAL N PATEL
# 933139   659714  EVOQ REMEDIES LTD.                 SHASHIKANT V SHARMA
#
#        corpdiro_date      committee_name  corpdiro_din  \
# ...
